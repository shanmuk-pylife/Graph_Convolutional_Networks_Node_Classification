# %% [markdown]
# <a href="https://colab.research.google.com/github/shanmuk-pylife/Graph_Convolutional_Networks_Node_Classification/blob/main/GCN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Node Classification using Graph Convolutional Networks**
#
# This node classification task uses CORA dataset from https://linqs.soe.ucsc.edu/data
#
# The dataset consists of **2708** nodes which correspond to scientific publications.
#
# The nodes are classified into **7** categories indicating the topics of each document.
#
# The edges indicate whether a document is cited by the other or vice versa.
#
# Each node has **1433** features which is described by a 0/1-valued vector, indicating the bag-of-words from the dictionary.
#
#
# This is an **undirected graph** problem

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# # **Importing Libraries**

# %%
# !pip install tensorflow==2.2.0
# Out:
# Requirement already satisfied: tensorflow==2.2.0 in /usr/local/lib/python3.7/dist-packages (2.2.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.3.3)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.12.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.36.2)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (2.2.2)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (3.12.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (2.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.15.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.32.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.1.2)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.6.3)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (2.10.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.19.5)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.1.0)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (54.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.27.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.23.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2020.12.5)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.8)

# %%
import numpy as np
import os
import networkx as nx
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# !pip install spektral
# Out:
# Requirement already satisfied: spektral in /usr/local/lib/python3.7/dist-packages (1.0.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from spektral) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from spektral) (1.1.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from spektral) (1.0.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from spektral) (0.22.2.post1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from spektral) (2.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from spektral) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from spektral) (2.23.0)
# Requirement already satisfied: tensorflow>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from spektral) (2.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from spektral) (4.41.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from spektral) (4.2.6)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->spektral) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->spektral) (2.8.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from networkx->spektral) (4.4.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->spektral) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->spektral) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->spektral) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->spektral) (2020.12.5)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (0.36.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (1.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (1.1.2)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (2.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (3.3.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (1.6.3)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (1.32.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (0.10.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (0.3.3)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (2.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (1.15.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (3.12.4)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (2.2.2)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->spektral) (0.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorflow>=2.1.0->spektral) (54.0.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (1.27.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (0.4.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (1.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (4.7.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (3.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (0.4.8)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (3.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.1.0->spektral) (3.1.0)

# %%
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.metrics import classification_report

from spektral.layers import GCNConv as GraphConv

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dropout, Dense
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping

from tensorflow.keras.regularizers import l2

from collections import Counter
from sklearn.manifold import TSNE

# %% [markdown]
# # **Data Loading and Preprocessing**
#
# We are going to use the edges connecting  (from file **cora.cites**).
#
# The nodes are loaded from file **cora.content**.

# %%
all_data = []
all_edges = []

for root,dirs,files in os.walk('/content/drive/MyDrive/Colab Notebooks/cora'):
    for file in files:
        if '.content' in file:
            with open(os.path.join(root,file),'r') as f:
                all_data.extend(f.read().splitlines())
        elif 'cites' in file:
            with open(os.path.join(root,file),'r') as f:
                all_edges.extend(f.read().splitlines())

                
#Shuffle the data because the raw data is ordered based on the label
random_state = 77
all_data = shuffle(all_data,random_state=random_state)

# %% [markdown]
# In **cora.content** file:
#
# The **first** element indicates the **node name**
#
# The **second** until the last second elements indicate the **node features**
#
# The **last** element indicates the **label of that particular node**
#
# In **cora.cites** file:
#
# Each line indicates the tuple of connected nodes
#
# # **Parsing the data**

# %%
#parse the data
labels = []
nodes = []
X = []

for i,data in enumerate(all_data):
    elements = data.split('\t')
    labels.append(elements[-1])
    X.append(elements[1:-1])
    nodes.append(elements[0])

X = np.array(X,dtype=int)
N = X.shape[0] #the number of nodes
F = X.shape[1] #the size of node features
print('X shape: ', X.shape)


#parse the edge
edge_list=[]
for edge in all_edges:
    e = edge.split('\t')
    edge_list.append((e[0],e[1]))

print('\nNumber of nodes (N): ', N)
print('\nNumber of features (F) of each node: ', F)
print('\nCategories: ', set(labels))

num_classes = len(set(labels))
print('\nNumber of classes: ', num_classes)
# Out:
# X shape:  (2708, 1433)
#
# Number of nodes (N):  2708
#
# Number of features (F) of each node:  1433
#
# Categories:  {'Neural_Networks', 'Reinforcement_Learning', 'Genetic_Algorithms', 'Theory', 'Probabilistic_Methods', 'Rule_Learning', 'Case_Based'}
#
# Number of classes:  7

# %% [markdown]
# # **Select examples for training, validation, and test then set the mask**

# %%
def limit_data(labels,limit=20,val_num=500,test_num=1000):
    '''
    Get the index of train, validation, and test data
    '''
    label_counter = dict((l, 0) for l in labels)
    train_idx = []

    for i in range(len(labels)):
        label = labels[i]
        if label_counter[label]<limit:
            #add the example to the training data
            train_idx.append(i)
            label_counter[label]+=1
        
        #exit the loop once we found 20 examples for each class
        if all(count == limit for count in label_counter.values()):
            break
    
    #get the indices that do not go to traning data
    rest_idx = [x for x in range(len(labels)) if x not in train_idx]
    #get the first val_num
    val_idx = rest_idx[:val_num]
    test_idx = rest_idx[val_num:(val_num+test_num)]
    return train_idx, val_idx,test_idx


train_idx,val_idx,test_idx = limit_data(labels)

# %%
#set the mask
train_mask = np.zeros((N,),dtype=bool)
train_mask[train_idx] = True

val_mask = np.zeros((N,),dtype=bool)
val_mask[val_idx] = True

test_mask = np.zeros((N,),dtype=bool)
test_mask[test_idx] = True

# %% [markdown]
# # **Show Data Distribution**

# %%
print("All Data Distribution: \n{}".format(Counter(labels)))
# Out:
# All Data Distribution:
# Counter({'Neural_Networks': 818, 'Probabilistic_Methods': 426, 'Genetic_Algorithms': 418, 'Theory': 351, 'Case_Based': 298, 'Reinforcement_Learning': 217, 'Rule_Learning': 180})

# %%
print("Training Data Distribution: \n{}".format(Counter([labels[i] for i in train_idx])))
# Out:
# Training Data Distribution:
# Counter({'Reinforcement_Learning': 20, 'Probabilistic_Methods': 20, 'Neural_Networks': 20, 'Case_Based': 20, 'Theory': 20, 'Genetic_Algorithms': 20, 'Rule_Learning': 20})

# %%
print("Validation Data Distribution: \n{}".format(Counter([labels[i] for i in val_idx])))
# Out:
# Validation Data Distribution:
# Counter({'Neural_Networks': 172, 'Genetic_Algorithms': 78, 'Probabilistic_Methods': 72, 'Theory': 63, 'Case_Based': 58, 'Reinforcement_Learning': 35, 'Rule_Learning': 22})

# %% [markdown]
# # **Convert the labels to one hot encoding**

# %%
def encode_label(labels):
    label_encoder = LabelEncoder()
    labels = label_encoder.fit_transform(labels)
    labels = to_categorical(labels)
    return labels, label_encoder.classes_

labels_encoded, classes = encode_label(labels)

# %% [markdown]
# # **Build a graph on NetworkX using the obtained nodes and edges list**

# %%
#build the graph
G = nx.Graph()
G.add_nodes_from(nodes)
G.add_edges_from(edge_list)

#obtain the adjacency matrix (A)
A = nx.adjacency_matrix(G)
print('Graph info: ', nx.info(G))
# Out:
# Graph info:  Name:
# Type: Graph
# Number of nodes: 2708
# Number of edges: 5278
# Average degree:   3.8981

# %% [markdown]
# # **Building and Training Graph Convolutional Networks**

# %%
# Parameters
channels = 16           # Number of channels in the first layer
dropout = 0.5           # Dropout rate for the features
l2_reg = 5e-4           # L2 regularization rate
learning_rate = 1e-2    # Learning rate
epochs = 200            # Number of training epochs
es_patience = 10        # Patience for early stopping

# Preprocessing operations
A = GraphConv.preprocess(A).astype('f4')

# Model definition
X_in = Input(shape=(F, ))
fltr_in = Input((N, ), sparse=True)

dropout_1 = Dropout(dropout)(X_in)
graph_conv_1 = GraphConv(channels,
                         activation='relu',
                         kernel_regularizer=l2(l2_reg),
                         use_bias=False)([dropout_1, fltr_in])

dropout_2 = Dropout(dropout)(graph_conv_1)
graph_conv_2 = GraphConv(num_classes,
                         activation='softmax',
                         use_bias=False)([dropout_2, fltr_in])

# Build model
model = Model(inputs=[X_in, fltr_in], outputs=graph_conv_2)
optimizer = Adam(lr=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              weighted_metrics=['acc'])
model.summary()

tbCallBack_GCN = tf.keras.callbacks.TensorBoard(
    log_dir='./Tensorboard_GCN_cora',
)
callback_GCN = [tbCallBack_GCN]
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 1433)]       0
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1433)         0           input_3[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 2708)]       0
# __________________________________________________________________________________________________
# gcn_conv_2 (GCNConv)            (None, 16)           22928       dropout_4[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16)           0           gcn_conv_2[0][0]
# __________________________________________________________________________________________________
# gcn_conv_3 (GCNConv)            (None, 7)            112         dropout_5[0][0]
#                                                                  input_4[0][0]
# ==================================================================================================
# Total params: 23,040
# Trainable params: 23,040
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train model
validation_data = ([X, A], labels_encoded, val_mask)
model.fit([X, A],
          labels_encoded,
          sample_weight=train_mask,
          epochs=epochs,
          batch_size=N,
          validation_data=validation_data,
          shuffle=False,
          callbacks=[
              EarlyStopping(patience=es_patience,  restore_best_weights=True),
              tbCallBack_GCN
          ])
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 469ms/step - loss: 0.1159 - acc: 0.1429 - val_loss: 0.3636 - val_acc: 0.2940
# Epoch 2/200
# 1/1 [==============================] - ETA: 0s - loss: 0.1083 - acc: 0.3357WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.220612). Check your callbacks.
# 1/1 [==============================] - 0s 283ms/step - loss: 0.1083 - acc: 0.3357 - val_loss: 0.3514 - val_acc: 0.4620
# Epoch 3/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.1012 - acc: 0.5429 - val_loss: 0.3374 - val_acc: 0.6040
# Epoch 4/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0956 - acc: 0.6500 - val_loss: 0.3248 - val_acc: 0.6220
# Epoch 5/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0907 - acc: 0.7286 - val_loss: 0.3138 - val_acc: 0.6440
# Epoch 6/200
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0856 - acc: 0.7714 - val_loss: 0.3039 - val_acc: 0.6560
# Epoch 7/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0794 - acc: 0.8500 - val_loss: 0.2941 - val_acc: 0.6760
# Epoch 8/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0773 - acc: 0.8071 - val_loss: 0.2844 - val_acc: 0.6920
# Epoch 9/200
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0751 - acc: 0.7857 - val_loss: 0.2755 - val_acc: 0.7080
# Epoch 10/200
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0714 - acc: 0.8286 - val_loss: 0.2671 - val_acc: 0.7220
# Epoch 11/200
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0707 - acc: 0.8571 - val_loss: 0.2596 - val_acc: 0.7360
# Epoch 12/200
# 1/1 [==============================] - 0s 263ms/step - loss: 0.0684 - acc: 0.8429 - val_loss: 0.2528 - val_acc: 0.7520
# Epoch 13/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0659 - acc: 0.8643 - val_loss: 0.2468 - val_acc: 0.7640
# Epoch 14/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0638 - acc: 0.9143 - val_loss: 0.2413 - val_acc: 0.7620
# Epoch 15/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0630 - acc: 0.9143 - val_loss: 0.2361 - val_acc: 0.7660
# Epoch 16/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0617 - acc: 0.9071 - val_loss: 0.2311 - val_acc: 0.7660
# Epoch 17/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0617 - acc: 0.9071 - val_loss: 0.2265 - val_acc: 0.7660
# Epoch 18/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0599 - acc: 0.9143 - val_loss: 0.2221 - val_acc: 0.7740
# Epoch 19/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0587 - acc: 0.9286 - val_loss: 0.2179 - val_acc: 0.7740
# Epoch 20/200
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0563 - acc: 0.9286 - val_loss: 0.2145 - val_acc: 0.7740
# Epoch 21/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0572 - acc: 0.9143 - val_loss: 0.2114 - val_acc: 0.7760
# Epoch 22/200
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0557 - acc: 0.9000 - val_loss: 0.2087 - val_acc: 0.7720
# Epoch 23/200
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0571 - acc: 0.8929 - val_loss: 0.2060 - val_acc: 0.7700
# Epoch 24/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0538 - acc: 0.9429 - val_loss: 0.2032 - val_acc: 0.7720
# Epoch 25/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0515 - acc: 0.9357 - val_loss: 0.2004 - val_acc: 0.7720
# Epoch 26/200
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0512 - acc: 0.9429 - val_loss: 0.1975 - val_acc: 0.7740
# Epoch 27/200
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0510 - acc: 0.9429 - val_loss: 0.1951 - val_acc: 0.7760
# Epoch 28/200
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0482 - acc: 0.9500 - val_loss: 0.1934 - val_acc: 0.7740
# Epoch 29/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0474 - acc: 0.9714 - val_loss: 0.1919 - val_acc: 0.7760
# Epoch 30/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0475 - acc: 0.9071 - val_loss: 0.1904 - val_acc: 0.7800
# Epoch 31/200
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0454 - acc: 0.9500 - val_loss: 0.1893 - val_acc: 0.7760
# Epoch 32/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0479 - acc: 0.9071 - val_loss: 0.1875 - val_acc: 0.7720
# Epoch 33/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0454 - acc: 0.9429 - val_loss: 0.1855 - val_acc: 0.7720
# Epoch 34/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0444 - acc: 0.9429 - val_loss: 0.1838 - val_acc: 0.7720
# Epoch 35/200
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0435 - acc: 0.9500 - val_loss: 0.1818 - val_acc: 0.7800
# Epoch 36/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0455 - acc: 0.9429 - val_loss: 0.1803 - val_acc: 0.7800
# Epoch 37/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0441 - acc: 0.9571 - val_loss: 0.1791 - val_acc: 0.7740
# Epoch 38/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0419 - acc: 0.9714 - val_loss: 0.1784 - val_acc: 0.7760
# Epoch 39/200
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0429 - acc: 0.9500 - val_loss: 0.1782 - val_acc: 0.7760
# Epoch 40/200
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0413 - acc: 0.9500 - val_loss: 0.1784 - val_acc: 0.7700
# Epoch 41/200
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0436 - acc: 0.9500 - val_loss: 0.1781 - val_acc: 0.7720
# Epoch 42/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0411 - acc: 0.9357 - val_loss: 0.1777 - val_acc: 0.7760
# Epoch 43/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0404 - acc: 0.9643 - val_loss: 0.1763 - val_acc: 0.7800
# Epoch 44/200
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0411 - acc: 0.9643 - val_loss: 0.1746 - val_acc: 0.7820
# Epoch 45/200
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0406 - acc: 0.9357 - val_loss: 0.1714 - val_acc: 0.7860
# Epoch 46/200
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0397 - acc: 0.9286 - val_loss: 0.1692 - val_acc: 0.7860
# Epoch 47/200
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0422 - acc: 0.9143 - val_loss: 0.1673 - val_acc: 0.7940
# Epoch 48/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0397 - acc: 0.9571 - val_loss: 0.1653 - val_acc: 0.7920
# Epoch 49/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0403 - acc: 0.9643 - val_loss: 0.1642 - val_acc: 0.7960
# Epoch 50/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0387 - acc: 0.9357 - val_loss: 0.1645 - val_acc: 0.7940
# Epoch 51/200
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0364 - acc: 0.9500 - val_loss: 0.1653 - val_acc: 0.7840
# Epoch 52/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0362 - acc: 0.9571 - val_loss: 0.1666 - val_acc: 0.7800
# Epoch 53/200
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0381 - acc: 0.9714 - val_loss: 0.1678 - val_acc: 0.7740
# Epoch 54/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0400 - acc: 0.9214 - val_loss: 0.1692 - val_acc: 0.7720
# Epoch 55/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0379 - acc: 0.9500 - val_loss: 0.1701 - val_acc: 0.7760
# Epoch 56/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0347 - acc: 0.9571 - val_loss: 0.1694 - val_acc: 0.7760
# Epoch 57/200
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0360 - acc: 0.9571 - val_loss: 0.1677 - val_acc: 0.7780
# Epoch 58/200
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0336 - acc: 0.9714 - val_loss: 0.1650 - val_acc: 0.7840
# Epoch 59/200
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0388 - acc: 0.9000 - val_loss: 0.1610 - val_acc: 0.7900
# Epoch 60/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0366 - acc: 0.9500 - val_loss: 0.1581 - val_acc: 0.7840
# Epoch 61/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0372 - acc: 0.9500 - val_loss: 0.1566 - val_acc: 0.7800
# Epoch 62/200
# 1/1 [==============================] - 0s 297ms/step - loss: 0.0349 - acc: 0.9643 - val_loss: 0.1562 - val_acc: 0.7820
# Epoch 63/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0328 - acc: 0.9929 - val_loss: 0.1572 - val_acc: 0.7760
# Epoch 64/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0343 - acc: 0.9714 - val_loss: 0.1591 - val_acc: 0.7740
# Epoch 65/200
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0340 - acc: 0.9429 - val_loss: 0.1614 - val_acc: 0.7680
# Epoch 66/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0357 - acc: 0.9500 - val_loss: 0.1651 - val_acc: 0.7660
# Epoch 67/200
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0351 - acc: 0.9357 - val_loss: 0.1667 - val_acc: 0.7600
# Epoch 68/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0360 - acc: 0.9786 - val_loss: 0.1669 - val_acc: 0.7640
# Epoch 69/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0338 - acc: 0.9429 - val_loss: 0.1645 - val_acc: 0.7780
# Epoch 70/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0331 - acc: 0.9643 - val_loss: 0.1618 - val_acc: 0.7780
# Epoch 71/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0335 - acc: 0.9286 - val_loss: 0.1576 - val_acc: 0.7820
# Epoch 72/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0329 - acc: 0.9643 - val_loss: 0.1544 - val_acc: 0.7860
# Epoch 73/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0340 - acc: 0.9643 - val_loss: 0.1526 - val_acc: 0.7880
# Epoch 74/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0338 - acc: 0.9500 - val_loss: 0.1526 - val_acc: 0.7800
# Epoch 75/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0350 - acc: 0.9429 - val_loss: 0.1536 - val_acc: 0.7860
# Epoch 76/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0314 - acc: 0.9714 - val_loss: 0.1561 - val_acc: 0.7840
# Epoch 77/200
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0334 - acc: 0.9643 - val_loss: 0.1585 - val_acc: 0.7800
# Epoch 78/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0338 - acc: 0.9429 - val_loss: 0.1598 - val_acc: 0.7860
# Epoch 79/200
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0308 - acc: 0.9714 - val_loss: 0.1613 - val_acc: 0.7740
# Epoch 80/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0334 - acc: 0.9643 - val_loss: 0.1624 - val_acc: 0.7720
# Epoch 81/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0320 - acc: 0.9643 - val_loss: 0.1631 - val_acc: 0.7720
# Epoch 82/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0324 - acc: 0.9643 - val_loss: 0.1624 - val_acc: 0.7760
# Epoch 83/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0305 - acc: 0.9714 - val_loss: 0.1589 - val_acc: 0.7800
# Epoch 84/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0300 - acc: 0.9786 - val_loss: 0.1552 - val_acc: 0.7820

# %%
# Evaluate model
X_te = X[test_mask]
A_te = A[test_mask,:][:,test_mask]
y_te = labels_encoded[test_mask]

y_pred = model.predict([X_te, A_te], batch_size=N)
report = classification_report(np.argmax(y_te,axis=1), np.argmax(y_pred,axis=1), target_names=classes)
print('GCN Classification Report: \n {}'.format(report))
# Out:
# GCN Classification Report:
#                          precision    recall  f1-score   support
#
#             Case_Based       0.76      0.74      0.75       114
#     Genetic_Algorithms       0.85      0.84      0.85       156
#        Neural_Networks       0.79      0.72      0.75       290
#  Probabilistic_Methods       0.82      0.74      0.78       172
# Reinforcement_Learning       0.68      0.81      0.74        85
#          Rule_Learning       0.52      0.78      0.63        60
#                 Theory       0.57      0.58      0.57       123
#
#               accuracy                           0.74      1000
#              macro avg       0.71      0.74      0.72      1000
#           weighted avg       0.75      0.74      0.74      1000

# %% [markdown]
# # **Get hidden layer representation for GCN**

# %%
layer_outputs = [layer.output for layer in model.layers]
activation_model = Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict([X,A],batch_size=N)

#Get t-SNE Representation
#get the hidden layer representation after the first GCN layer
x_tsne = TSNE(n_components=2).fit_transform(activations[3])

# %%
def plot_tSNE(labels_encoded,x_tsne):
    color_map = np.argmax(labels_encoded, axis=1)
    plt.figure(figsize=(10,10))
    for cl in range(num_classes):
        indices = np.where(color_map==cl)
        indices = indices[0]
        plt.scatter(x_tsne[indices,0], x_tsne[indices, 1], label=cl)
    plt.legend()
    plt.show()
    
plot_tSNE(labels_encoded,x_tsne)

# %% [markdown]
# # **Comparison to Fully-Connected Neural Networks**
#
# # **Building and Training FNN**

# %%
es_patience = 10
optimizer = Adam(lr=1e-2)
l2_reg = 5e-4
epochs = 200

#Compare with FNN
#Construct the model
model_fnn = Sequential()
model_fnn.add(Dense(
                    128,
                    input_dim=X.shape[1],
                    activation=tf.nn.relu,
                    kernel_regularizer=tf.keras.regularizers.l2(l2_reg))
             )
model_fnn.add(Dropout(0.5))
model_fnn.add(Dense(256, activation=tf.nn.relu))
model_fnn.add(Dropout(0.5))
model_fnn.add(Dense(num_classes, activation=tf.keras.activations.softmax))


model_fnn.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              weighted_metrics=['acc'])


#define TensorBoard
tbCallBack_FNN = TensorBoard(
    log_dir='./Tensorboard_FNN_cora',
)

#Train model
validation_data_fnn = (X, labels_encoded, val_mask)
model_fnn.fit(
                X,labels_encoded,
                sample_weight=train_mask,
                epochs=epochs,
                batch_size=N,
                validation_data=validation_data_fnn,
                shuffle=False,
                callbacks=[
                  EarlyStopping(patience=es_patience,  restore_best_weights=True),
                  tbCallBack_FNN
          ])
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 382ms/step - loss: 0.2187 - acc: 0.1500 - val_loss: 0.4329 - val_acc: 0.3000
# Epoch 2/200
# 1/1 [==============================] - ETA: 0s - loss: 0.1736 - acc: 0.4143WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.158568). Check your callbacks.
# 1/1 [==============================] - 0s 257ms/step - loss: 0.1736 - acc: 0.4143 - val_loss: 0.3970 - val_acc: 0.4460
# Epoch 3/200
# 1/1 [==============================] - 0s 258ms/step - loss: 0.1382 - acc: 0.6643 - val_loss: 0.3636 - val_acc: 0.5100
# Epoch 4/200
# 1/1 [==============================] - 0s 260ms/step - loss: 0.1109 - acc: 0.7214 - val_loss: 0.3313 - val_acc: 0.5500
# Epoch 5/200
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0838 - acc: 0.7786 - val_loss: 0.3006 - val_acc: 0.5640
# Epoch 6/200
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0669 - acc: 0.8429 - val_loss: 0.2766 - val_acc: 0.5720
# Epoch 7/200
# 1/1 [==============================] - 0s 258ms/step - loss: 0.0523 - acc: 0.9000 - val_loss: 0.2659 - val_acc: 0.5820
# Epoch 8/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0435 - acc: 0.9786 - val_loss: 0.2679 - val_acc: 0.5880
# Epoch 9/200
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0436 - acc: 0.9500 - val_loss: 0.2844 - val_acc: 0.5880
# Epoch 10/200
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0437 - acc: 0.9714 - val_loss: 0.3149 - val_acc: 0.5680
# Epoch 11/200
# 1/1 [==============================] - 0s 251ms/step - loss: 0.0434 - acc: 0.9857 - val_loss: 0.3448 - val_acc: 0.5520
# Epoch 12/200
# 1/1 [==============================] - 0s 249ms/step - loss: 0.0421 - acc: 0.9929 - val_loss: 0.3870 - val_acc: 0.5220
# Epoch 13/200
# 1/1 [==============================] - 0s 240ms/step - loss: 0.0405 - acc: 1.0000 - val_loss: 0.4274 - val_acc: 0.5080
# Epoch 14/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0399 - acc: 0.9929 - val_loss: 0.4394 - val_acc: 0.5020
# Epoch 15/200
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0368 - acc: 0.9929 - val_loss: 0.4296 - val_acc: 0.5200
# Epoch 16/200
# 1/1 [==============================] - 0s 265ms/step - loss: 0.0350 - acc: 0.9857 - val_loss: 0.4142 - val_acc: 0.5460
# Epoch 17/200
# 1/1 [==============================] - 0s 263ms/step - loss: 0.0306 - acc: 1.0000 - val_loss: 0.4008 - val_acc: 0.5520

# %%
# Evaluate model
y_pred = model_fnn.predict(X_te)
report = classification_report(np.argmax(y_te,axis=1), np.argmax(y_pred,axis=1), target_names=classes)
print('FCNN Classification Report: \n {}'.format(report))
# Out:
# FCNN Classification Report:
#                          precision    recall  f1-score   support
#
#             Case_Based       0.45      0.65      0.53       114
#     Genetic_Algorithms       0.72      0.79      0.75       156
#        Neural_Networks       0.75      0.51      0.61       290
#  Probabilistic_Methods       0.67      0.53      0.59       172
# Reinforcement_Learning       0.55      0.51      0.53        85
#          Rule_Learning       0.31      0.58      0.40        60
#                 Theory       0.41      0.46      0.43       123
#
#               accuracy                           0.57      1000
#              macro avg       0.55      0.57      0.55      1000
#           weighted avg       0.61      0.57      0.58      1000

# %% [markdown]
# # **Get hidden layer representation for FNN**

# %%
layer_outputs = [layer.output for layer in model_fnn.layers] 
activation_model = Model(inputs=model_fnn.input, outputs=layer_outputs)
activations = activation_model.predict([X])

# %%
x_tsne = TSNE(n_components=2).fit_transform(activations[3])
plot_tSNE(labels_encoded,x_tsne)

# %%
### END OF NOTEBOOK ###
